# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from matplotlib.figure import Figure
encoding = 'utf-8'

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = np.cos(x)
plt.plot(x,y)
plt.show()
fig.savefig(fname='plot.png',)

# %%
fig = plt.figure()
x = np.random.randint(0,10,size = 10)
y = np.random.randint(0,10,size = 10)
plt.scatter(x,y)
fig.savefig('scatter.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = np.random.randint(1,10,size = 10)
plt.bar(x,y)
fig.savefig('bar.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = np.random.randint(1,10,size = 10)
plt.stem(x,y)
fig.savefig('stem.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = np.random.randint(1,10,size = 10)
plt.step(x,y)
fig.savefig('E:/Program/Markdown/Matplotlib/step.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
r = np.random.randint(1,5,size=10)
y1 = np.add(x,r)
y2 = np.add(x,-r)
plt.plot(x,x)
plt.fill_between(x,y1,y2,alpha = 0.5)
fig.savefig('E:/Program/Markdown/Matplotlib/fill_between.png')

# %%
fig = plt.figure()
x, y = np.meshgrid(np.linspace(-3,3,10),np.linspace(-3,3,10))
z = x*y
plt.imshow(z)
fig.savefig('E:/Program/Markdown/Matplotlib/imshow.png')

# %%
fig = plt.figure()
x, y = np.meshgrid(np.linspace(0,3,10),np.linspace(-3,3,20))
z = y * x
plt.pcolormesh(z)
fig.savefig('E:/Program/Markdown/Matplotlib/pcolormesh.png')

# %%
fig = plt.figure()
x, y = np.meshgrid(np.linspace(-3,3,200),np.linspace(-3,3,200))
z = x**1/2 * y
level = np.linspace(z.min(),z.max(),10)
plt.contour(x,y,z,level)
fig.savefig('E:/Program/Markdown/Matplotlib/contour.png')

# %%
fig = plt.figure()
x, y = np.meshgrid(np.linspace(-3,3,200),np.linspace(-3,3,200))
z = x**1/2 * y
level = np.linspace(z.min(),z.max(),10)
plt.contourf(x,y,z,level)
fig.savefig('E:/Program/Markdown/Matplotlib/contourf.png')

# %%
fig = plt.figure()
x, y = np.meshgrid([1, 2, 3, 4], [1, 2, 3, 4])
angle = np.pi / 180 * np.array([[15, 30, 35, 45],
                                [25, 40, 55, 60],
                                [35, 50, 65, 75],
                                [45, 60, 75, 90]]) # 构造角度
amplitude = np.array([[5, 10, 25, 50],
                      [10, 15, 30, 60],
                      [15, 26, 50, 70],
                      [20, 45, 80, 100]]) # 构造
u = amplitude * np.sin(angle)
v = amplitude * np.cos(angle)
plt.barbs(x,y,u,v)
fig.savefig('E:/Program/Markdown/Matplotlib/barbs.png')

# %%
fig = plt.figure()
x, y = np.meshgrid(np.linspace(-3,3,5),np.linspace(-3,3,5))
u = x + y
v = x - y
plt.quiver(x,y,u,v)
fig.savefig('E:/Program/Markdown/Matplotlib/quiver.png')

# %%
fig = plt.figure()
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
V = np.diff(Z[1:, :], axis=1)
U = -np.diff(Z[:, 1:], axis=0)
plt.streamplot(X[1:, 1:], Y[1:, 1:], U, V)
fig.savefig('E:/Program/Markdown/Matplotlib/streamplot.png')

# %%
fig = plt.figure()
r = np.random.normal(0,2,200)
x = 5+r
plt.hist(x)
fig.savefig('E:/Program/Markdown/Matplotlib/hist.png')

# %%
fig = plt.figure()
x = np.random.normal((1,3,5),(1.25,1.5,1.75),(200,3))
plt.boxplot(x)
fig.savefig('E:/Program/Markdown/Matplotlib/boxplot.png')

# %%
fig = plt.figure()
x = [3,3.4,3.8]
y = [3,2,1]
error = [0.2,0.4,0.3]
plt.errorbar(x,y,error)
fig.savefig('E:/Program/Markdown/Matplotlib/errorbar.png')

# %%
fig = plt.figure()
x = np.random.normal((1,3,5),(1.25,1.5,1.75),(200,3))
plt.violinplot(x)
fig.savefig('E:/Program/Markdown/Matplotlib/violinplot.png')

# %%
fig = plt.figure()
x = np.random.gamma(4,(3,50))
plt.eventplot(x,orientation='vertical')
fig.savefig('E:/Program/Markdown/Matplotlib/eventplot.png')

# %%
fig = plt.figure()
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.hist2d(x,y)
fig.savefig('E:/Program/Markdown/Matplotlib/hist2d.png')

# %%
fig = plt.figure()
x = np.random.randn(100)
y = np.random.randn(100)
plt.hexbin(x,y,gridsize=10)
fig.savefig('E:/Program/Markdown/Matplotlib/hexbin.png')

# %%
fig = plt.figure()
x = [1,2,3,4]
plt.pie(x)
fig.savefig('E:/Program/Markdown/Matplotlib/pie.png')

# %%
fig = plt.figure()
x = np.random.uniform(-3, 3, 200)
y = np.random.uniform(-3, 3, 200)
z = (1 - x/2 + x**2 + y**2) * np.exp(-x**2 - y**2)
levels = np.linspace(z.min(), z.max(), 7)
plt.tricontour(x,y,z,levels)
fig.savefig('E:/Program/Markdown/Matplotlib/tricontour.png')

# %%
fig = plt.figure()
x = np.random.uniform(-3, 3, 200)
y = np.random.uniform(-3, 3, 200)
z = (1 - x/2 + x**2 + y**2) * np.exp(-x**2 - y**2)
levels = np.linspace(z.min(), z.max(), 7)
plt.tricontourf(x,y,z,levels)
fig.savefig('E:/Program/Markdown/Matplotlib/tricontourf.png')

# %%
fig = plt.figure()
x = np.random.uniform(-3, 3, 200)
y = np.random.uniform(-3, 3, 200)
z = (1 - x/2 + x**2 + y**2) * np.exp(-x**2 - y**2)
levels = np.linspace(z.min(), z.max(), 7)
plt.tripcolor(x,y,z,levels)
fig.savefig('E:/Program/Markdown/Matplotlib/tripcolor.png')

# %%
fig = plt.figure()
x = np.random.uniform(-3, 3, 200)
y = np.random.uniform(-3, 3, 200)
plt.triplot(x,y)
fig.savefig('E:/Program/Markdown/Matplotlib/triplot.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = np.cos(x)
plt.plot(x,y,color = '0')
fig.savefig('E:/Program/Markdown/Matplotlib/plotcolor.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = np.cos(x)
plt.plot(x,y,'g--')
fig.savefig('E:/Program/Markdown/Matplotlib/plot-.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = np.cos(x)
plt.plot(x,y,color = (0.5,0.4,0.8,0.8))
fig.savefig('E:/Program/Markdown/Matplotlib/plotrgba.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = np.cos(x)
plt.plot(x,y,c= '#0f5212')
fig.savefig('E:/Program/Markdown/Matplotlib/plothex.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = np.cos(x)
plt.plot(x,y,c= '0.8')
fig.savefig('E:/Program/Markdown/Matplotlib/plotgrey.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
plt.plot(x,y,linestyle = (0,(1,2,5,1)),linewidth = 2)
fig.savefig('E:/Program/Markdown/Matplotlib/plotlinestyle.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
plt.plot(x,y,linestyle = (0,(1,2,5,1)),linewidth = 4)
fig.savefig('E:/Program/Markdown/Matplotlib/plotlinewidth.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = x
plt.plot(x,y,marker = 'o')
fig.savefig('E:/Program/Markdown/Matplotlib/plotmarker.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = x
plt.plot(x,y,label = 'o')

# %%
fig = plt.figure()
x = np.random.randint(0,10,size = 10)
y = np.random.randint(0,10,size = 10)
plt.scatter(x,y,s = 500,marker='*')
fig.savefig('E:/Program/Markdown/Matplotlib/scatters.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = np.random.randint(1,10,size = 10)
plt.bar(x,y,width=0.2)
fig.savefig('E:/Program/Markdown/Matplotlib/barweight.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = np.random.randint(1,10,size = 10)
plt.bar(x,y,bottom=2)
fig.savefig('E:/Program/Markdown/Matplotlib/barbottom.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,10)
y = np.random.randint(1,10,size = 10)
plt.bar(x,y,align='edge')
fig.savefig('E:/Program/Markdown/Matplotlib/baralign.png')

# %%
fig = plt.figure()
x = [1,2,3,4]
plt.pie(x,labels=['one','two','three','four'])
fig.savefig('E:/Program/Markdown/Matplotlib/pielabels.png')

# %%
fig = plt.figure()
x = [1,2,3,4]
plt.pie(x,shadow=True)
fig.savefig('E:/Program/Markdown/Matplotlib/pieshadow.png')

# %%
fig = plt.figure()
x = [1,2,3,4]
plt.pie(x,pctdistance=0.1)
fig.savefig('E:/Program/Markdown/Matplotlib/piedistance.png')

# %%
fig = plt.figure()
x = np.arange(14)
y = np.sin(x / 2)

plt.step(x, y + 2, label='pre (default)')
plt.plot(x, y + 2, 'o--', color='grey', alpha=0.3)

plt.step(x, y + 1, where='mid', label='mid')
plt.plot(x, y + 1, 'o--', color='grey', alpha=0.3)

plt.step(x, y, where='post', label='post')
plt.plot(x, y, 'o--', color='grey', alpha=0.3)
fig.savefig('E:/Program/Markdown/Matplotlib/stepwithplot.png')

# %%
fig = plt.figure()
r = np.random.normal(0,2,200)
x = 5+r
plt.hist(x,bins=5)
fig.savefig('E:/Program/Markdown/Matplotlib/histbin.png')

# %%
fig = plt.figure()
r = np.random.normal(0,2,200)
x = 5+r
plt.hist(x,range=[0,20])
fig.savefig('E:/Program/Markdown/Matplotlib/histrange.png')

# %%
fig = plt.figure()
r = np.random.normal(0,2,200)
x = 5+r
plt.hist(x,bottom=50)
fig.savefig('E:/Program/Markdown/Matplotlib/histbottom.png')

# %%
fig = plt.figure()
x = np.random.randn(100)
y = x
plt.plot(x,y)
plt.title('This is a title',fontdict={'family':'Times New Roman','fontsize': 20,'color': 'b'},loc = 'left',y=1.05)
fig.savefig('E:/Program/Markdown/Matplotlib/title.png')

# %%
fig = plt.figure()
x = np.random.randn(100)
y = x
plt.plot(x,y)
plt.xlabel('xlabel',loc='right',c = 'r')
plt.ylabel('ylabel',loc='top',fontsize = 20)
fig.savefig('E:/Program/Markdown/Matplotlib/xylabel.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
z = x**2
plt.plot(x,y,x,z)
plt.legend(['$x$','$x^2$'])
fig.savefig('E:/Program/Markdown/Matplotlib/legends.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
plt.plot(x,y)
plt.grid(axis='x',c = 'r',linestyle = '-.')
fig.savefig('E:/Program/Markdown/Matplotlib/grid.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
plt.plot(x,y)
plt.text(3,5,'Hello',fontsize = 20)
fig.savefig('E:/Program/Markdown/Matplotlib/text.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
plt.plot(x,y)
plt.xlim(-10,20)
plt.ylim(0,20)
fig.savefig('E:/Program/Markdown/Matplotlib/xylim.png')

# %%
fig = plt.figure()
x = np.linspace(1,10,100)
y = x**10
plt.plot(x,y)
plt.yscale('symlog')
fig.savefig('E:/Program/Markdown/Matplotlib/xyscale.png')

# %%
fig = plt.figure()
x = np.linspace(1,5,10)
y = x*10
plt.plot(x,y)
plt.xticks(ticks = [1,2,3,4,5],labels=['2000','2001','2002','2003','2004'])
fig.savefig('E:/Program/Markdown/Matplotlib/xyticks.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
plt.plot(x,y)
plt.axhline(6,0,0.6,linestyle = '--')
plt.axvline(6,0,0.6,linestyle = '--')
fig.savefig('E:/Program/Markdown/Matplotlib/axvhline.png')

# %%
fig = plt.figure()
x = np.linspace(0,10,100)
y = x
plt.plot(x,y)
plt.axhspan(6,0,0.6,color = 'r')
plt.axvspan(6,0,0.6)
fig.savefig('E:/Program/Markdown/Matplotlib/axvspan.png')
