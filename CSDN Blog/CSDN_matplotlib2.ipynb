# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots(2,2,sharex=True,sharey=False)

# %%
# 制造数据
x = np.random.randint(0,100,15)
y = np.random.randint(0,100,15)
fig,ax = plt.subplots()
ax.scatter(x,y,c='r',label='data1',marker='d')
ax.scatter(y,x,c='b',label='data2')
ax.set_title('This is an example')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.grid(linestyle='-.')
ax.legend()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,sharex=True,sharey=False)

# %%
# 制造数据
x = np.random.randint(0,100,15)
y = np.random.randint(0,100,15)
fig, (ax1,ax2) = plt.subplots(1,2,sharex=True,sharey=False)
ax1.scatter(x,y,c='r',label='data1',marker='d')
ax2.scatter(y,x,c='b',label='data2')
ax1.set_title('This is an example')
ax2.set_xlabel('xlabel')
ax1.set_ylabel('ylabel')
ax2.grid(linestyle='-.')
ax1.legend()

# %%
from matplotlib import style

# %%
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
style.use('seaborn')
x = np.random.randint(0,100,15)
y = np.random.randint(0,100,15)
fig,ax = plt.subplots()
ax.scatter(x,y,c='r',label='data1',marker='d')
ax.scatter(y,x,c='b',label='data2')
ax.set_title('This is an example')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.grid(linestyle='-.')
ax.legend()

# %%
style.use('dark_background')
x = np.random.randint(0,100,15)
y = np.random.randint(0,100,15)
fig,ax = plt.subplots()
ax.scatter(x,y,c='r',label='data1',marker='d')
ax.scatter(y,x,c='b',label='data2')
ax.set_title('This is an example')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.grid(linestyle='-.')
ax.legend()
